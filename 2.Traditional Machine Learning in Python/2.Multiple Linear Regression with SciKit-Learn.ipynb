# %%
import pandas as pd

df = pd.read_excel("other files/images_analyzed.xlsx")
print(df.head())
# Out:
#    User  Time  Coffee  Age  Images_Analyzed
# 0     1     8       0   23               20
# 1     1    13       0   23               14
# 2     1    17       0   23               18
# 3     1    22       0   23               15
# 4     1     8       2   23               22

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()
sns.lmplot(x='Time', y='Images_Analyzed', data=df, hue='Age')
plt.figure()
sns.lmplot(x='Coffee', y='Images_Analyzed', data=df, hue='Age')

# %%
import numpy as np
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df[['Time', 'Coffee', 'Age']], df.Images_Analyzed)

print(reg.coef_)
# Out:
# [-0.35642282 -0.3475     -0.04279945]

# %%
print(reg.predict([[13,2,23]]))
# Out:
# [18.8767522]
