# %%
# Import libraries

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

# %%
# Load MNIST data

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

import random

plt.figure()
plt.imshow(x_train[random.randint(0, len(x_train)),:,:,:], cmap="gray")

# %%
# Adding some noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)


print(x_train_noisy.shape)
# Out:
# (60000, 28, 28, 1)

# %%
#Displaying images with noise
plt.figure(figsize=(20, 2))
for i in range(1,10):
    ax = plt.subplot(1, 10, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap="binary")
plt.show()

# %%
# Set the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
 
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(1, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         2312
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 8)          0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d (UpSampling2D  (None, 8, 8, 8)          0
#  )
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_1 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 32)        2336
#
#  up_sampling2d_2 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 7,009
# Trainable params: 7,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train and save the model

model.fit(x_train_noisy, x_train, epochs=10, batch_size=256, shuffle=True, 
          validation_data=(x_test_noisy, x_test))



model.evaluate(x_test_noisy, x_test)

model.save('denoising_autoencoder.model')
# Out:
# Epoch 1/10
# 235/235 [==============================] - 40s 168ms/step - loss: 0.0524 - val_loss: 0.0400
# Epoch 2/10
# 235/235 [==============================] - 42s 177ms/step - loss: 0.0371 - val_loss: 0.0338
# Epoch 3/10
# 235/235 [==============================] - 42s 178ms/step - loss: 0.0324 - val_loss: 0.0305
# Epoch 4/10
# 235/235 [==============================] - 41s 174ms/step - loss: 0.0299 - val_loss: 0.0285
# Epoch 5/10
# 235/235 [==============================] - 40s 169ms/step - loss: 0.0283 - val_loss: 0.0273
# Epoch 6/10
# 235/235 [==============================] - 40s 169ms/step - loss: 0.0273 - val_loss: 0.0264
# Epoch 7/10
# 235/235 [==============================] - 41s 172ms/step - loss: 0.0263 - val_loss: 0.0258
# Epoch 8/10
# 235/235 [==============================] - 41s 173ms/step - loss: 0.0256 - val_loss: 0.0251
# Epoch 9/10
# 235/235 [==============================] - 40s 172ms/step - loss: 0.0251 - val_loss: 0.0244
# Epoch 10/10
# 235/235 [==============================] - 40s 171ms/step - loss: 0.0245 - val_loss: 0.0249
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0249
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: denoising_autoencoder.model\assets
# INFO:tensorflow:Assets written to: denoising_autoencoder.model\assets

# %%
no_noise_img = model.predict(x_test_noisy)

plt.figure(figsize=(40, 4))
for i in range(10):
    # display original
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap="binary")
    
    # display reconstructed (after noise removed) image
    ax = plt.subplot(3, 20, 40 +i+ 1)
    plt.imshow(no_noise_img[i].reshape(28, 28), cmap="binary")

plt.show()
# Out:
# 313/313 [==============================] - 3s 8ms/step
